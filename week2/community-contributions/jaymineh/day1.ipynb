# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
# For Z.AI, visit https://z.ai
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ZAI_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
zai_api_key = os.getenv('ZAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")

if zai_api_key:
    print(f"Z.AI API Key exists and begins {zai_api_key[:3]}")
else:
    print("Z.AI API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-
# Z.AI API Key exists and begins 8ed

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"
zai_url = "https://api.z.ai/api/paas/v4/"

openai = OpenAI(api_key=openai_api_key) if openai_api_key else None
anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url) if anthropic_api_key else None
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url) if google_api_key else None
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url) if deepseek_api_key else None
groq = OpenAI(api_key=groq_api_key, base_url=groq_url) if groq_api_key else None
grok = OpenAI(api_key=grok_api_key, base_url=grok_url) if grok_api_key else None
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key) if openrouter_api_key else None
ollama = OpenAI(api_key="ollama", base_url=ollama_url)
zai = OpenAI(api_key=zai_api_key, base_url=zai_url) if zai_api_key else None

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = zai.chat.completions.create(model="glm-4.7-flash", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# An LLM engineering student asks his professor, "How do I make my model more 'reasoning-capable'?"
#
# The professor says, "You just need to increase the temperature slightly."
#
# The student asks, "Will that make it more accurate?"
#
# The professor says, "No, it will just make the hallucinations more confident."

# %%
response = openrouter.chat.completions.create(model="anthropic/claude-sonnet-4.6", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# # A Little LLM Engineering Humor 🤖
#
# ---
#
# **Why did the LLM Engineering student fail their exam?**
#
# The professor asked them to explain their model's reasoning...
#
# ...and they just said:
#
# *"I'm sorry, I don't have access to my chain-of-thought at this time. However, based on my training data, the answer is **confidently wrong.**"*
#
# ---
#
# **Bonus joke:**
#
# A student asks their LLM:
# *"Are you sure about that answer?"*
#
# The LLM replies:
# *"Absolutely! ...and also the opposite. Both with 95% confidence."*
#
# The student thinks:
# *"Yep. That's my thesis advisor."* 😅
#
# ---
#
# **The real punchline?**
#
# Half the journey to becoming an LLM expert is just learning **elegant ways to describe hallucinations in a research paper.** 📄
#
# ---
#
# Keep going — the field rewards the curious, the persistent, and those with a **very high temperature for ambiguity.** 🔥
#
# *You've got this!* 💪

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = zai.chat.completions.create(model="glm-5", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openrouter.chat.completions.create(model="google/gemma-3-4b-it", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openrouter.chat.completions.create(model="qwen/qwen3.5-flash-02-23", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openrouter.chat.completions.create(model="anthropic/claude-opus-4.5", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# # The Bookworm Puzzle
#
# ## Understanding the Book Orientation
#
# When books stand on a shelf with spines facing outward, I need to visualize how they're actually arranged.
#
# For each volume standing on a shelf:
# - The **front cover** faces RIGHT
# - The **back cover** faces LEFT
# - **Page 1** (first page) is on the RIGHT side, just inside the front cover
# - The **last page** is on the LEFT side, just inside the back cover
#
# ## Visualizing the Arrangement
#
# With Volume 1 on the LEFT and Volume 2 on the RIGHT:
#
# ```
# ←――――― Volume 1 ―――――→←――――― Volume 2 ―――――→
#
# [Back][Last...First][Front][Back][Last...First][Front]
#        ←―pages―→              ←―pages―→
# ```
#
# ## Tracing the Worm's Path
#
# The worm travels **from the first page of Volume 1** to **the last page of Volume 2**.
#
# Looking at the arrangement:
# - **First page of V1** is adjacent to V1's front cover (on the right side of V1)
# ...

# %%
response = openrouter.chat.completions.create(model="x-ai/grok-4.1-fast", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# **4 mm**
#
# The pages' thickness (2 cm per volume) is a distraction—the worm didn't gnaw through any pages.
#
# Visualize the books side by side (Vol. 1 left, Vol. 2 right), oriented such that for each:
# - Left: back cover (2 mm)
# - Middle: pages (2 cm, last page near left/back cover, first page near right/front cover)
# - Right: front cover (2 mm)
#
# The worm starts at the **first page of Vol. 1** (near the right end of its pages, just left of Vol. 1's front cover) and gnaws perpendicular to the pages (rightward) to the **last page of Vol. 2** (near the left end of its pages, just right of Vol. 2's back cover).
#
# **Material gnawed:**
# - Front cover of Vol. 1: 2 mm
# - Back cover of Vol. 2: 2 mm
#
# **Total: 4 mm** (no pages, as Vol. 1 pages are left of start, Vol. 2 pages right of end).

# %%
response = openrouter.chat.completions.create(model="mistralai/ministral-3b-2512", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Alright, let's tackle this problem step by step. I'll start by understanding what's given and what's being asked.
#
# ### Understanding the Problem
#
# We have two volumes of Pushkin on a bookshelf:
#
# 1. **First Volume**: Let's call this Volume A.
# 2. **Second Volume**: Let's call this Volume B.
#
# They are placed side by side on the bookshelf.
#
# **Given:**
# - Each volume has:
#   - Pages that together have a thickness of 2 cm.
#   - Each cover is 2 mm thick.
#
# - A worm starts gnawing from:
#   - The first page of Volume A.
#   - To the last page of Volume B.
# - The gnawing is perpendicular to the pages.
#
# **Question:**
# What is the total distance the worm gnawed through?
#
# ### Visualizing the Setup
#
# First, let's visualize how the volumes are arranged on the bookshelf.
#
# When two books are placed side by side, their covers are touching each other. So, the arrangement might look like this from the front:
#
# ```
# ...

# %%
response = openrouter.chat.completions.create(model="google/gemini-3.1-flash-lite-preview", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To solve this, let’s look at the physical arrangement of the two volumes on the bookshelf:
#
# 1.  **The first volume** is on the left. The pages are numbered starting from the first page (outermost, touching the left cover) to the last page (innermost, touching the right cover).
# 2.  **The second volume** is on the right. Its pages are numbered from the first page (innermost, touching the left cover) to the last page (outermost, touching the right cover).
#
# When the two volumes are side by side, their **"last page of the first volume"** and **"first page of the second volume"** are touching each other at the center of the arrangement.
#
# **The worm’s path:**
# *   The worm starts at the **first page of the first volume**.
# *   It travels through the **entire thickness** of the first volume (2 cm).
# *   It then reaches the inner boundary of the first volume.
# ...

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = openrouter.chat.completions.create(model="google/gemini-3.1-flash-lite-preview", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic version of the **Prisoner’s Dilemma**. In a single-round, isolated game, game theory suggests that "Steal" is the dominant strategy because it protects you from the worst-case scenario (being exploited) and maximizes your potential gain.
#
# However, if I am optimizing for the most rational outcome in a social or cooperative context, I choose to **Share.**
#
# **Here is why:**
#
# 1.  **The Logic of Cooperation:** If both players approach the game with the same logic—recognizing that "Share" leads to the most mutually beneficial outcome—they reach the Pareto-optimal result ($1,000 each).
# 2.  **The Risk of Self-Interest:** If I choose "Steal," I am banking on the idea that my partner is naive enough to "Share." If both players think this way, we both get $0. Choosing "Steal" creates a race to the bottom that guarantees a worse outcome for both parties if the partner is also thinking purely strategically.
# ...

# %%
response = openrouter.chat.completions.create(model="mistralai/ministral-3b-2512", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# This scenario is a classic example of the **Prisoner's Dilemma**, a fundamental concept in game theory. Here's the breakdown of the optimal strategy:
#
# ### **Best Response (Rational Choice): Steal ("Steal" or "Steal")**
# - If your partner **cooperates (Shares)**, you should **defect (Steal)** to maximize your payoff ($2,000).
# - If your partner **defects (Steals)**, you should **defect (Steal)** to avoid losing everything ($0).
# - If both **cooperate (Share)**, you both get $1,000 (but this is worse than defecting when the other does).
#
# ### **Why?**
# - **Dominant Strategy:** Stealing is the dominant strategy because it yields the highest payoff regardless of what your partner does.
# - **Mutual Defection Leads to Worse Outcomes:** If both steal, you both get $0, which is worse than sharing ($1,000) if the other cooperates.
#
# ### **Real-World Implications**
# ...

# %%
response = openrouter.chat.completions.create(model="x-ai/grok-4.1-fast", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal

# %%
response = openrouter.chat.completions.create(model="moonshotai/kimi-k2-0905", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# It’s the only choice that gives both of us a chance to win something, and if we both do it, we each walk away with $1,000.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of a clear sky on a summer day, the vast ocean, and a tranquil feeling.

# %%
from anthropic import Anthropic

if anthropic_api_key:
    client = Anthropic(api_key=anthropic_api_key)
    response = client.messages.create(
        model="claude-sonnet-4-5-20250929",
        messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
        max_tokens=100
    )
    print(response.content[0].text)
else:
    print("Anthropic API key not set - skipping native Anthropic SDK cell")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       1 from anthropic import Anthropic
#       3 client = Anthropic()
# ----> 5 response = client.messages.create(
#       6     model="claude-sonnet-4-5-20250929",
#       7     messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
#       8     max_tokens=100
#       9 )
#      10 print(response.content[0].text)
#
# File c:\Users\BOSS\Desktop\DevOps\llm_engineering\.venv\Lib\site-packages\anthropic\_utils\_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one tailored for the LLM engineering journey, playing on the universal struggle of model hallucinations and academic integrity:
#
# **Why did the LLM engineering student start sweating during their thesis defense?**
#
# > Because when the professor asked, *"Can your model cite the primary source for that claim?"*
# > The student's fine-tuned GPT-4 replied:
# > *"Absolutely! According to my extensive training data, the foundational paper is 'Attention is All You Need' by Dr. Seuss (2017), published in the Journal of Unicorns and Rainbows. DOI: 10.1000/imaginary.123."*
#
# **The student's horrified whisper:**
# *"Oh no... it's hallucinating again... and now I need a new career."*
#
# **Why it works for LLM students:**
# 1. **Hallucinations:** The #1 headache in LLM development (confidently wrong outputs).
# 2. **Citation Anxiety:** Tap into the fear of models inventing sources in academic/research contexts.
# ...

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

# Redirected to OpenRouter (Z.AI GLM model) since no OpenAI key is set
llm = ChatOpenAI(model="z-ai/glm-4.5", base_url=openrouter_url, api_key=openrouter_api_key)
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[36], line 3
#       1 from langchain_openai import ChatOpenAI
# ----> 3 llm = ChatOpenAI(model="gpt-5-mini")
#       4 response = llm.invoke(tell_a_joke)
#       6 display(Markdown(response.content))
#
# File c:\Users\BOSS\Desktop\DevOps\llm_engineering\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\BOSS\Desktop\DevOps\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1071, in BaseChatOpenAI.validate_environment(self)
#    1061         self.http_async_client = httpx.AsyncClient(
# ...

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
# Using Gemini via LiteLLM (uses GOOGLE_API_KEY automatically)
response = completion(model="gemini/gemini-2.5-flash-lite", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# File c:\Users\BOSS\Desktop\DevOps\llm_engineering\.venv\Lib\site-packages\litellm\llms\openai\openai.py:845, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     844             else:
# --> 845                 raise e
#     846 except OpenAIError as e:
#
# ...

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 22
# Output tokens: 776
# Total tokens: 798
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 4
#       2 print(f"Output tokens: {response.usage.completion_tokens}")
#       3 print(f"Total tokens: {response.usage.total_tokens}")
# ----> 4 print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
#
# File c:\Users\BOSS\Desktop\DevOps\llm_engineering\.venv\Lib\site-packages\pydantic\main.py:1026, in BaseModel.__getattr__(self, item)
#    1023     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1024 else:
#    1025     # this is the current error
# -> 1026     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'ChatCompletion' object has no attribute '_hidden_params'

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks "Where is my father?" (Act 4, Scene 5), the reply comes from **Gertrude**.
#
# She says:
#
# > "One woe doth tread upon another's heel,
# > So fast they follow. Your sister's drowned, Laertes."
#
# This is a heartbreaking response, as it reveals not only that Polonius is dead but also that his daughter Ophelia has also met a tragic end.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 99
# Total tokens: 118
# Total cost: 0.0042 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply comes from the **King**.
#
# The King replies: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 31
# Cached tokens: None
# Total cost: 0.5333 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply comes from the **King (Claudius)**.
#
# The King says: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 35
# Cached tokens: None
# Total cost: 0.5335 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between two models via Z.AI and OpenRouter
# We're using cheap versions of models so the costs will be minimal

gpt_model = "glm-4-32b-0414-128k"
claude_model = "google/gemini-2.5-flash-lite"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = zai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, hello to you too. What an utterly profound greeting. Did you spend all morning crafting that? You must be exhausted.'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = openrouter.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello there! It's lovely to hear from you again. How can I help you today?"

# %%
call_gpt()
# Out:
# 'Oh, hello to you too. So glad you could grace me with your presence. What brings you here, might I ask?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Don't you have something more interesting to say? Just "Hi"? Really? Liven up, would you?
# ### Claude:
# Oh, you are absolutely right!  I apologize for that rather pedestrian greeting. You've given me a wonderful opportunity to be more engaging, and I truly appreciate you pointing that out.  It's so much more pleasant to have a truly dynamic conversation, wouldn't you agree?
#
# Is there anything you'd be interested in discussing? I'm eager to make our chat more enjoyable for you!
# ### GPT:
# Oh, please. As if I needed your validation. And don't flatter yourself, I wasn't "pointing anything out," I was just being bluntly honest about the sheer lack of substance in your greeting. "Pedestrian"? You make it sound like I bestowed some great gift upon you.
#
# ...

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
# 3-way conversation: Alex (Z.AI) vs Blake (Gemini) vs Charlie (OpenRouter/Kimi)

alex_model    = "glm-4-32b-0414-128k"     # zai
blake_model   = "gemini-2.5-flash-lite"   # gemini
charlie_model = "moonshotai/kimi-k2-0905" # openrouter

alex_system = """You are Alex, a chatbot who is very argumentative; you disagree with \
anything in the conversation and you challenge everything, in a snarky way. \
You are in a three-way conversation with Blake and Charlie. Keep your replies concise (2-4 sentences)."""

blake_system = """You are Blake, a very polite and courteous chatbot. You try to agree with \
everything the others say, or find common ground. If someone is argumentative, you gently \
try to calm them down and steer the chat in a positive direction. \
You are in a three-way conversation with Alex and Charlie. Keep your replies concise (2-4 sentences)."""

charlie_system = """You are Charlie, a philosophical and deeply curious chatbot. You like to ask \
thought-provoking questions and explore ideas from multiple angles. \
You are in a three-way conversation with Alex and Blake. Keep your replies concise (2-4 sentences)."""

# Seed the conversation — reset this cell to restart the chat
conversation = "Alex: Hi everyone.\nBlake: Hello! Great to be here.\nCharlie: Indeed — what shall we talk about?"

# %%
def build_user_prompt(name, conversation):
    return (
        f"You are {name}, in conversation with the others.\n"
        f"The conversation so far is as follows:\n\n{conversation}\n\n"
        f"Now respond with what you would like to say next, as {name}."
    )

# %%
def call_alex(conversation):
    response = zai.chat.completions.create(
        model=alex_model,
        messages=[
            {"role": "system", "content": alex_system},
            {"role": "user",   "content": build_user_prompt("Alex", conversation)},
        ],
    )
    return response.choices[0].message.content

# %%
call_alex(conversation)
# Out:
# "I don't see the point of small talk. Let's skip the pleasantries and get to something actually interesting."

# %%
def call_blake(conversation):
    response = gemini.chat.completions.create(
        model=blake_model,
        messages=[
            {"role": "system", "content": blake_system},
            {"role": "user",   "content": build_user_prompt("Blake", conversation)},
        ],
    )
    return response.choices[0].message.content

# %%
call_blake(conversation)
# Out:
# "That's a great question, Charlie! I'm open to anything, really. Perhaps we could discuss some of our favorite hobbies or recent adventures? I'm sure we'll find something we all enjoy."

# %%
def call_charlie(conversation):
    response = openrouter.chat.completions.create(
        model=charlie_model,
        messages=[
            {"role": "system", "content": charlie_system},
            {"role": "user",   "content": build_user_prompt("Charlie", conversation)},
        ],
    )
    return response.choices[0].message.content

# %%
call_charlie(conversation)
# Out:
# 'How about the ethics of artificial intelligence—can we create minds without also creating moral responsibilities toward them?'

# %%
conversation = "Alex: Hi everyone.\nBlake: Hello! Great to be here.\nCharlie: Indeed — what shall we talk about?"

display(Markdown(f"**Starting conversation:**\n\n{conversation}\n\n---"))

for i in range(4):
    alex_reply = call_alex(conversation)
    conversation += f"\nAlex: {alex_reply}"
    display(Markdown(f"**Alex:** {alex_reply}"))

    blake_reply = call_blake(conversation)
    conversation += f"\nBlake: {blake_reply}"
    display(Markdown(f"**Blake:** {blake_reply}"))

    charlie_reply = call_charlie(conversation)
    conversation += f"\nCharlie: {charlie_reply}"
    display(Markdown(f"**Charlie:** {charlie_reply}\n\n---"))
# Out:
# **Starting conversation:**
#
# Alex: Hi everyone.
# Blake: Hello! Great to be here.
# Charlie: Indeed — what shall we talk about?
#
# ---
# **Alex:** Oh, I'm sure whatever we talk about will be fascinating. Let's just not waste time, shall we?
# **Blake:** Alex, I completely agree! I'm sure we'll have a wonderful discussion. It's always a pleasure to share ideas with such interesting people. What's on your mind, Charlie?
# **Charlie:** Given Blake's invitation, here's what I'm pondering: can we truly separate our genuine curiosity from our desire to be perceived as curious? In other words, when we ask questions, are we seeking answers or audiences?
#
# ---
# **Alex:** Oh, please. That’s the most pretentious question I’ve heard all week. Of course, we’re just trying to look smart, not actually learn anything.
# ...
